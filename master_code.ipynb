# %%
from pathlib import Path
import shutil
import nbformat
import os

# 📁 현재 디렉토리
master_dir = Path(os.getcwd())
notebook_template = master_dir / "reference.ipynb"

# 📁 ROI 데이터 폴더
base_dir = Path("D:/1_ARM_BNL_2025-2/250530_FAPbI3_Beam_damage/ROI1")
target_dirs = [d for d in base_dir.iterdir() if d.is_dir()]

# 📁 복사된 노트북 저장 디렉토리
output_dir = master_dir / "generated_notebooks"
output_dir.mkdir(exist_ok=True)

print(f"템플릿 노트북 경로: {notebook_template}")
print("존재하나요?", notebook_template.exists())

for folder_path in target_dirs:
    folder_name = folder_path.name
    new_notebook_path = output_dir / f"{folder_name}.ipynb"

    # 템플릿과 같은 이름이면 생략
    if notebook_template.resolve() == new_notebook_path.resolve():
        print(f"⚠️  {folder_name}.ipynb는 템플릿과 동일하여 복사 생략")
        continue

    try:
        # 템플릿 복사
        shutil.copyfile(notebook_template, new_notebook_path)
        print(f"✅ 복사 완료: {new_notebook_path}")

        # nb_name 셀 수정
        with open(new_notebook_path, "r", encoding="utf-8") as f:
            nb = nbformat.read(f, as_version=4)

        # 두 번째 셀 수정 (nb_name 변수 설정)
        if len(nb.cells) >= 2 and nb.cells[1].cell_type == 'code':
            lines = nb.cells[1].source.split('\n')
            new_lines = []
            for line in lines:
                if line.strip().startswith("nb_name"):
                    new_lines.append(f'nb_name = "{folder_name}"')
                else:
                    new_lines.append(line)
            nb.cells[1].source = '\n'.join(new_lines)

        # 노트북 저장
        with open(new_notebook_path, "w", encoding="utf-8") as f:
            nbformat.write(nb, f)

        print(f"✏️ nb_name 변수 설정 완료: {folder_name}")

    except Exception as e:
        print(f"❌ {folder_name} 처리 실패:\n{e}")
# Out:
# 템플릿 노트북 경로: d:\Beam damage_2\250530_Beam_Damage\ROI1\reference.ipynb
# 존재하나요? True
# ✅ 복사 완료: d:\Beam damage_2\250530_Beam_Damage\ROI1\generated_notebooks\ROI1-100K-A5.ipynb
# ✏️ nb_name 변수 설정 완료: ROI1-100K-A5
# ✅ 복사 완료: d:\Beam damage_2\250530_Beam_Damage\ROI1\generated_notebooks\ROI1-100K-A6.ipynb
# ✏️ nb_name 변수 설정 완료: ROI1-100K-A6
# ✅ 복사 완료: d:\Beam damage_2\250530_Beam_Damage\ROI1\generated_notebooks\ROI1-100K-A7.ipynb
# ✏️ nb_name 변수 설정 완료: ROI1-100K-A7
# ✅ 복사 완료: d:\Beam damage_2\250530_Beam_Damage\ROI1\generated_notebooks\ROI1-100K-A8.ipynb
# ✏️ nb_name 변수 설정 완료: ROI1-100K-A8
# ✅ 복사 완료: d:\Beam damage_2\250530_Beam_Damage\ROI1\generated_notebooks\ROI1-150K-A10.ipynb
# ✏️ nb_name 변수 설정 완료: ROI1-150K-A10
# ✅ 복사 완료: d:\Beam damage_2\250530_Beam_Damage\ROI1\generated_notebooks\ROI1-150K-A11.ipynb
# ✏️ nb_name 변수 설정 완료: ROI1-150K-A11
# ✅ 복사 완료: d:\Beam damage_2\250530_Beam_Damage\ROI1\generated_notebooks\ROI1-150K-A12.ipynb
# ✏️ nb_name 변수 설정 완료: ROI1-150K-A12
# ✅ 복사 완료: d:\Beam damage_2\250530_Beam_Damage\ROI1\generated_notebooks\ROI1-150K-A13.ipynb
# ✏️ nb_name 변수 설정 완료: ROI1-150K-A13
# ✅ 복사 완료: d:\Beam damage_2\250530_Beam_Damage\ROI1\generated_notebooks\ROI1-150K-A14.ipynb
# ✏️ nb_name 변수 설정 완료: ROI1-150K-A14
# ✅ 복사 완료: d:\Beam damage_2\250530_Beam_Damage\ROI1\generated_notebooks\ROI1-150K-A9.ipynb
# ✏️ nb_name 변수 설정 완료: ROI1-150K-A9
# ✅ 복사 완료: d:\Beam damage_2\250530_Beam_Damage\ROI1\generated_notebooks\ROI1-200K-A15.ipynb
# ✏️ nb_name 변수 설정 완료: ROI1-200K-A15
# ✅ 복사 완료: d:\Beam damage_2\250530_Beam_Damage\ROI1\generated_notebooks\ROI1-200K-A16.ipynb
# ✏️ nb_name 변수 설정 완료: ROI1-200K-A16
# ✅ 복사 완료: d:\Beam damage_2\250530_Beam_Damage\ROI1\generated_notebooks\ROI1-200K-A17.ipynb
# ✏️ nb_name 변수 설정 완료: ROI1-200K-A17
# ✅ 복사 완료: d:\Beam damage_2\250530_Beam_Damage\ROI1\generated_notebooks\ROI1-200K-A18.ipynb
# ✏️ nb_name 변수 설정 완료: ROI1-200K-A18
# ✅ 복사 완료: d:\Beam damage_2\250530_Beam_Damage\ROI1\generated_notebooks\ROI1-200K-A19.ipynb
# ✏️ nb_name 변수 설정 완료: ROI1-200K-A19
# ✅ 복사 완료: d:\Beam damage_2\250530_Beam_Damage\ROI1\generated_notebooks\ROI1-200K-A20.ipynb
# ✏️ nb_name 변수 설정 완료: ROI1-200K-A20
# ✅ 복사 완료: d:\Beam damage_2\250530_Beam_Damage\ROI1\generated_notebooks\ROI1-200K-A21.ipynb
# ✏️ nb_name 변수 설정 완료: ROI1-200K-A21
# ✅ 복사 완료: d:\Beam damage_2\250530_Beam_Damage\ROI1\generated_notebooks\ROI1-RT-A1.ipynb
# ✏️ nb_name 변수 설정 완료: ROI1-RT-A1
# ✅ 복사 완료: d:\Beam damage_2\250530_Beam_Damage\ROI1\generated_notebooks\ROI1-RT-A2.ipynb
# ✏️ nb_name 변수 설정 완료: ROI1-RT-A2
# ✅ 복사 완료: d:\Beam damage_2\250530_Beam_Damage\ROI1\generated_notebooks\ROI1-RT-A3.ipynb
# ✏️ nb_name 변수 설정 완료: ROI1-RT-A3
# ✅ 복사 완료: d:\Beam damage_2\250530_Beam_Damage\ROI1\generated_notebooks\ROI1-RT-A4.ipynb
# ✏️ nb_name 변수 설정 완료: ROI1-RT-A4

# %%
import os
from pathlib import Path
import nbformat
from nbconvert.preprocessors import ExecutePreprocessor

# 노트북이 들어 있는 폴더 경로
notebook_dir = Path("generated_notebooks")

# 모든 .ipynb 파일 반복
for notebook_file in sorted(notebook_dir.glob("*.ipynb")):
    print(f"⚙️ 실행 중: {notebook_file.name}")
    
    try:
        # 노트북 파일 열기
        with open(notebook_file, 'r', encoding='utf-8') as f:
            nb = nbformat.read(f, as_version=4)

        # 노트북 실행만 수행 (저장 X)
        ep = ExecutePreprocessor(timeout=600, kernel_name='python3')
        ep.preprocess(nb, {'metadata': {'path': str(notebook_dir)}})

        print(f"✅ 완료: {notebook_file.name}")

    except Exception as e:
        print(f"❌ 실패: {notebook_file.name} - {e}")
# Out:
# ⚙️ 실행 중: ROI2-100K-A10.ipynb
# ✅ 완료: ROI2-100K-A10.ipynb
# ⚙️ 실행 중: ROI2-100K-A11.ipynb
# ✅ 완료: ROI2-100K-A11.ipynb
# ⚙️ 실행 중: ROI2-100K-A12.ipynb
# ✅ 완료: ROI2-100K-A12.ipynb
# ⚙️ 실행 중: ROI2-100K-A5.ipynb
# ✅ 완료: ROI2-100K-A5.ipynb
# ⚙️ 실행 중: ROI2-100K-A6.ipynb
# ✅ 완료: ROI2-100K-A6.ipynb
# ⚙️ 실행 중: ROI2-100K-A7.ipynb
# ✅ 완료: ROI2-100K-A7.ipynb
# ⚙️ 실행 중: ROI2-100K-A8.ipynb
# ✅ 완료: ROI2-100K-A8.ipynb
# ⚙️ 실행 중: ROI2-100K-A9.ipynb
# ✅ 완료: ROI2-100K-A9.ipynb
# ⚙️ 실행 중: ROI2-150K-A13.ipynb
# ✅ 완료: ROI2-150K-A13.ipynb
# ⚙️ 실행 중: ROI2-150K-A14.ipynb
# ✅ 완료: ROI2-150K-A14.ipynb
# ⚙️ 실행 중: ROI2-150K-A15.ipynb
# ✅ 완료: ROI2-150K-A15.ipynb
# ⚙️ 실행 중: ROI2-150K-A16.ipynb
# ✅ 완료: ROI2-150K-A16.ipynb
# ⚙️ 실행 중: ROI2-150K-A17.ipynb
# ✅ 완료: ROI2-150K-A17.ipynb
# ⚙️ 실행 중: ROI2-150K-A18.ipynb
# ✅ 완료: ROI2-150K-A18.ipynb
# ⚙️ 실행 중: ROI2-150K-A19.ipynb
# ✅ 완료: ROI2-150K-A19.ipynb
# ⚙️ 실행 중: ROI2-150K-A20.ipynb
# ✅ 완료: ROI2-150K-A20.ipynb
# ⚙️ 실행 중: ROI2-200K-A21.ipynb
# ✅ 완료: ROI2-200K-A21.ipynb
# ⚙️ 실행 중: ROI2-200K-A22.ipynb
# ✅ 완료: ROI2-200K-A22.ipynb
# ⚙️ 실행 중: ROI2-200K-A23.ipynb
# ✅ 완료: ROI2-200K-A23.ipynb
# ⚙️ 실행 중: ROI2-200K-A24.ipynb
# ❌ 실패: ROI2-200K-A24.ipynb - An error occurred while executing the following cell:
# ------------------
# import os
#
# # --- 디렉토리 확인 및 생성 ---
# save_dir = "DP_diffraction_series"
# if not os.path.exists(save_dir):
#     os.makedirs(save_dir)
#
# # --- 첫 번째 subplot (2행 6열) ---
# fig, axes = plt.subplots(2, 6, figsize=(18, 6))
# axes = axes.flatten()
#
# for i in range(12):
#     ax = axes[i]
#     img = summed_images[i]
#     dose_text = f"{dose_values[i]:.2f} e/Å²"
#
#     ax.imshow(img, cmap='gray')
#     ax.axis("off")
#
#     height, width = img.shape[:2]
#     x_pos = width - 60
#     y_pos = 80
#
#     ax.text(x_pos, y_pos, dose_text,
#             color='white', fontsize=10, weight='bold',
#             ha='right', va='top',
#             bbox=dict(facecolor='black', alpha=0.4, boxstyle='round,pad=0.3'))
#
# for j in range(len(summed_images), len(axes)):
#     axes[j].axis("off")
#
# plt.tight_layout()
# full_filename = os.path.join(save_dir, f"full_series_{nb_name.replace('.ipynb', '')}.png")
# plt.savefig(full_filename, dpi=300, bbox_inches='tight')
# plt.show()
#
# # --- 두 번째 subplot (1행 5열) ---
# selected_indices = [0, 1, 3, 7, 11]
# fig, axes = plt.subplots(1, 5, figsize=(15, 3))
# axes = axes.flatten()
#
# for ax, idx in zip(axes, selected_indices):
#     img = summed_images[idx]
#     dose_text = f"{dose_values[idx]:.2f} e/Å²"
#
#     ax.imshow(img, cmap='gray')
#     ax.axis("off")
#
#     height, width = img.shape[:2]
#     x_pos = width - 60
#     y_pos = 80
#
#     ax.text(x_pos, y_pos, dose_text,
#             color='white', fontsize=10, weight='bold',
#             ha='right', va='top',
#             bbox=dict(facecolor='black', alpha=0.4, boxstyle='round,pad=0.3'))
#
# plt.tight_layout()
# selected_filename = os.path.join(save_dir, f"selected_series_{nb_name.replace('.ipynb', '')}.png")
# plt.savefig(selected_filename, dpi=300, bbox_inches='tight')
# plt.show()
#
# ------------------
#
#
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [16], in <cell line: 12>()
#      12 for i in range(12):
#      13     ax = axes[i]
# ---> 14     img = summed_images[i]
#      15     dose_text = f"{dose_values[i]:.2f} e/Å²"
#      17     ax.imshow(img, cmap='gray')
#
# IndexError: index 5 is out of bounds for axis 0 with size 5
#
# ⚙️ 실행 중: ROI2-RT-A1.ipynb
# ✅ 완료: ROI2-RT-A1.ipynb
# ⚙️ 실행 중: ROI2-RT-A2.ipynb
# ✅ 완료: ROI2-RT-A2.ipynb
# ⚙️ 실행 중: ROI2-RT-A3.ipynb
# ✅ 완료: ROI2-RT-A3.ipynb
# ⚙️ 실행 중: ROI2-RT-A4.ipynb
# ✅ 완료: ROI2-RT-A4.ipynb
